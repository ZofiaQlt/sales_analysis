# %% [markdown]
# <img src="img/logo.png">

# %% [markdown]
# # Chargement des librairies

# %%
import numpy as np
import pandas as pd
from mylib.fonction_exploration import exploration
import warnings
warnings.filterwarnings('ignore')

print("Version numpy : " + np.__version__)
print("Version pandas : " + pd.__version__)

chemin_erp = 'src/erp.xlsx'
chemin_liaison = 'src/liaison.xlsx'
chemin_web = 'src/web.xlsx'
# Out:
# Version numpy : 1.23.5
# Version pandas : 1.4.4

# %% [markdown]
# # Chargement des fichiers

# %%
erp = pd.read_excel(chemin_erp)
liaison = pd.read_excel(chemin_liaison)
web = pd.read_excel(chemin_web)

# %% [markdown]
# # Utilisation de la fonction exploration

# %% [markdown]
# ## Fichier **erp**.xlsx

# %%
exploration(erp)
# Out:
# --------------------------
# Aperçu du DataFrame (head)
# --------------------------
#
#    product_id  onsale_web  price  stock_quantity stock_status
# 0        3847           1   24.2               0   outofstock
# 1        3849           1   34.3               0   outofstock
# 2        3850           1   20.8               0   outofstock
# 3        4032           1   14.1               0   outofstock
# 4        4039           1   46.0               0   outofstock
#
# ------------------------------------
# Aperçu de la fin du DataFrame (tail)
# ------------------------------------
#
#      product_id  onsale_web  price  stock_quantity stock_status
# 820        7203           0   45.0              30      instock
# 821        7204           0   45.0               9      instock
# 822        7247           1   54.8              23      instock
# 823        7329           0   26.5              14      instock
# 824        7338           1   16.3              45      instock
#
# ...

# %% [markdown]
# ### Remarques sur le fichier erp.xlsx

# %% [markdown]
# 1. Aucune valeur nulle
# 2. Pas de doublons
# 3. Tous les formats de données sont corrects
# 4. Prix moyen de 32.42 euros et prix max de 225 euros
# 5. Stock moyen de 26.5 et stock max de 578 par product_id

# %% [markdown]
# ## Fichier **liaison**.xlsx

# %%
exploration(liaison)
# Out:
# --------------------------
# Aperçu du DataFrame (head)
# --------------------------
#
#    product_id id_web
# 0        3847  15298
# 1        3849  15296
# 2        3850  15300
# 3        4032  19814
# 4        4039  19815
#
# ------------------------------------
# Aperçu de la fin du DataFrame (tail)
# ------------------------------------
#
#      product_id   id_web
# 820        7203      NaN
# 821        7204      NaN
# 822        7247  13127-1
# 823        7329  14680-1
# 824        7338    16230
#
# ---------------------------------
# Échantillon du DataFrame (sample)
# ---------------------------------
#
#      product_id id_web
# 712        6216  15070
# 752        6632  15794
# 9          4045  16041
# 715        6223  15324
# 772        6898    NaN
#
# ---------------------------------------
# Nombre de lignes et de colonnes (shape)
# ---------------------------------------
#
# (825, 2)
#
# -------------------------
# Type des données (dtypes)
# -------------------------
# ...

# %% [markdown]
# ### Remarques sur le fichier liaison.xlsx

# %% [markdown]
# 1. 91 valeurs nulles dans id_web
# 2. Pas de doublons
# 3. Tous les formats de données sont corrects

# %% [markdown]
# ## Fichier **web**.xlsx

# %%
exploration(web)
# Out:
# --------------------------
# Aperçu du DataFrame (head)
# --------------------------
#
#                    sku  virtual  downloadable  rating_count  average_rating  \
# 0  bon-cadeau-25-euros        0             0             0             0.0
# 1                15298        0             0             0             0.0
# 2                15296        0             0             0             0.0
# 3                15300        0             0             0             0.0
# 4                19814        0             0             0             0.0
#
#    total_sales tax_status  tax_class  post_author           post_date  ...  \
# 0         10.0    taxable        NaN          1.0 2018-06-01 13:53:46  ...
# 1          6.0    taxable        NaN          2.0 2018-02-08 12:58:52  ...
# 2          0.0    taxable        NaN          2.0 2018-02-08 13:49:41  ...
# 3          0.0    taxable        NaN          2.0 2018-02-08 14:08:36  ...
# ...

# %% [markdown]
# ### Remarques sur le fichier web.xlsx

# %% [markdown]
# 1. Beaucoup de valeurs nulles, seules les colonnes "virtual", "downloadable" et "rating_count" n'en ont pas
# 2. 82 doublons
# 3. Tous les formats de données sont corrects
